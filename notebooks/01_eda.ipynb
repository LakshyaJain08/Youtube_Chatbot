# %% [markdown]
# # 01. Exploratory Data Analysis: YouTube Transcripts
# Analysis of transcript lengths, segment durations, word distributions, and subtitle density.

# %%
from src.components.data_ingestion import DataIngestion
from src.utils.common import extract_video_id

video_id = 'Gfr50f6ZBvo'
ingestion = DataIngestion()
payload = ingestion.ingest(video_id)
print('Video:', payload['metadata']['title'])
print('Total Segments:', len(payload['segments']))
print('Total Words:', payload['metadata']['total_words'])
print('Duration (seconds):', payload['metadata']['duration_seconds'])
